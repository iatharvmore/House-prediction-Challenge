# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 67.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 66.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 40.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.1 MB/s eta 0:00:00
# ...

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
import pandas as pd
from pycaret.datasets import get_data
tdata = pd.read_csv("/content/train.csv")
from pycaret.regression import *
s = setup(tdata, target = 'SalePrice', session_id = 123)
s.X_transformed
# Out:
# <style type="text/css">
# #T_6f250_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6f250" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f250_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6f250_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f250_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f250_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6f250_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6f250_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f250_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6f250_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_6f250_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from pycaret.regression import RegressionExperiment
exp = RegressionExperiment()

# %%
type(exp)
# Out:
# pycaret.regression.oop.RegressionExperiment

# %%
exp.setup(tdata, target = 'SalePrice', session_id = 123)
# Out:
# <style type="text/css">
# #T_a5499_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a5499" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5499_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a5499_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5499_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5499_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a5499_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a5499_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5499_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a5499_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_a5499_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_9ce7f th {
#   text-align: left;
# }
# ...

# %%
best
# Out:
# GradientBoostingRegressor(random_state=123)

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'error')

# %%
plot_model(best, plot = 'feature')

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff80b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff80b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff80b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ff80b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ff80b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ff80b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ff80b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ff80b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff80b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff80b_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ff80b_row0_col1" class="data row0 col1" >15391.2677</td>
# ...

# %%
holdout_pred.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 147    148          60       RL          NaN     9505   Pave   NaN      IR1
# 676    677          70       RM         60.0     9600   Pave  Grvl      Reg
# 1304  1305         160       RM         32.0     3363   Pave   NaN      Reg
# 1372  1373          60       RL         75.0     9750   Pave   NaN      Reg
# 1427  1428          50       RL         60.0    10930   Pave  Grvl      Reg
#
#      LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold  \
# 147          Lvl    AllPub  ...    NaN   NaN         NaN       0      5
# 676          Lvl    AllPub  ...    NaN   NaN         NaN       0      5
# 1304         Lvl    AllPub  ...    NaN   NaN         NaN       0      4
# 1372         Lvl    AllPub  ...    NaN   NaN         NaN       0      6
# 1427         Bnk    AllPub  ...    NaN   NaN         NaN       0      4
#
#      YrSold SaleType  SaleCondition  SalePrice  prediction_label
# ...

# %%
test_data =pd.read_csv("/content/test.csv")
test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
predictions = predict_model(best, data = test_data)
predictions.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         HLS    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  prediction_label
# ...

# %%
data = predictions[["Id",'prediction_label']]

# %%
submission_data = data.rename(columns={'prediction_label':'SalePrice'})

# %%
submission_data
# Out:
#         Id      SalePrice
# 0     1461  123517.267529
# 1     1462  158268.878809
# 2     1463  176300.055509
# 3     1464  178591.995846
# 4     1465  196799.605012
# ...    ...            ...
# 1454  2915   77598.161625
# 1455  2916   87179.370050
# 1456  2917  164591.168107
# 1457  2918  115316.656820
# 1458  2919  221638.223929
#
# [1459 rows x 2 columns]

# %%
submission_data.to_csv('submission_data.csv', index=False)

# %%
sample_data = pd.read_csv('/content/sample_submission.csv')
